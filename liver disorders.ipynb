# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/liver-disorders/bupa.data', header = None)

# %%
df.columns = ['mcv', 'alkphos', 'sgpt', 'sgot', 'gammagt', 'drinks', 'selector']

# %%
a = df.hist(figsize=(10,10))
a.view()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E5A3748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E728AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E744FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E2D46D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E2FCD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E2FCDA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E353A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E386160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E39BE80>]],
#       dtype=object)

# %%
for i in L:
    cdf = df[i].value_counts().sort_index().cumsum()
    cdf.plot(legend =  i, figsize=(10,8))

# %%
import seaborn as sns

x = df.iloc[:,0].values.tolist()
# sns.distplot(x)
#              hist_kws=dict(cumulative=True),
#              kde_kws=dict(cumulative=True))
