# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header = None)

# %%
# 1. sepal length in cm 
# 2. sepal width in cm 
# 3. petal length in cm 
# 4. petal width in cm 
# 5. class: 
# -- Iris Setosa 
# -- Iris Versicolour 
# -- Iris Virginica

# %%
df.columns = ['sepal_le', 'sepal_wi', 'pental_le', 'pental_wi','label']

# %%
df.describe()
# Out:
#          sepal_le    sepal_wi   pental_le   pental_wi
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.hist(cumulative=True, density=1, bins = 20, figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-939039493993> in <module>()
#       1 df.hist(cumulative=True, density=1, bins = 20, figsize=(10,5))
# ----> 2 df.iloc[:,-1].value_counts.sum().plot()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df['label'].value_counts().plot(kind='bar')

# %%
# df['sepal_le'] =  pd.cut(df['sepal_le'], bins = 7, labels = np.arange(6), right = False).astype('int')
# for i in df.columns.values.tolist():
L =  df.columns.values.tolist()
L.pop(-1)
for i in L:
    df[i] = pd.cut(df[i], bins = 7, labels = np.arange(7), right = False).astype('int')

# %%
df
# Out:
#      sepal_le  sepal_wi  pental_le  pental_wi           label
# 0           1         4          0          0     Iris-setosa
# 1           1         2          0          0     Iris-setosa
# 2           0         3          0          0     Iris-setosa
# 3           0         3          0          0     Iris-setosa
# 4           1         4          0          0     Iris-setosa
# 5           2         5          0          0     Iris-setosa
# 6           0         4          0          0     Iris-setosa
# 7           1         4          0          0     Iris-setosa
# 8           0         2          0          0     Iris-setosa
# 9           1         3          0          0     Iris-setosa
# 10          2         4          0          0     Iris-setosa
# 11          0         4          0          0     Iris-setosa
# 12          0         2          0          0     Iris-setosa
# 13          0         2          0          0     Iris-setosa
# 14          2         5          0          0     Iris-setosa
# 15          2         6          0          0     Iris-setosa
# 16          2         5          0          0     Iris-setosa
# 17          1         4          0          0     Iris-setosa
# 18          2         5          0          0     Iris-setosa
# 19          1         5          0          0     Iris-setosa
# 20          2         4          0          0     Iris-setosa
# 21          1         4          0          0     Iris-setosa
# 22          0         4          0          0     Iris-setosa
# 23          1         3          0          1     Iris-setosa
# 24          0         4          1          0     Iris-setosa
# 25          1         2          0          0     Iris-setosa
# 26          1         4          0          0     Iris-setosa
# 27          1         4          0          0     Iris-setosa
# 28          1         4          0          0     Iris-setosa
# 29          0         3          0          0     Iris-setosa
# ..        ...       ...        ...        ...             ...
# 120         5         3          5          6  Iris-virginica
# 121         2         2          4          5  Iris-virginica
# 122         6         2          6          5  Iris-virginica
# 123         3         2          4          4  Iris-virginica
# 124         4         3          5          5  Iris-virginica
# 125         5         3          5          4  Iris-virginica
# 126         3         2          4          4  Iris-virginica
# 127         3         2          4          4  Iris-virginica
# 128         4         2          5          5  Iris-virginica
# 129         5         2          5          4  Iris-virginica
# 130         6         2          6          5  Iris-virginica
# 131         6         5          6          5  Iris-virginica
# 132         4         2          5          6  Iris-virginica
# 133         3         2          4          4  Iris-virginica
# 134         3         1          5          3  Iris-virginica
# 135         6         2          6          6  Iris-virginica
# 136         3         4          5          6  Iris-virginica
# 137         4         3          5          4  Iris-virginica
# 138         3         2          4          4  Iris-virginica
# 139         5         3          5          5  Iris-virginica
# 140         4         3          5          6  Iris-virginica
# 141         5         3          4          6  Iris-virginica
# 142         2         2          4          5  Iris-virginica
# 143         4         3          5          6  Iris-virginica
# 144         4         3          5          6  Iris-virginica
# 145         4         2          4          6  Iris-virginica
# 146         3         1          4          5  Iris-virginica
# 147         4         2          4          5  Iris-virginica
# 148         3         4          5          6  Iris-virginica
# 149         3         2          4          4  Iris-virginica
#
# [150 rows x 5 columns]
